# %%
pip install pandas numpy matplotlib seaborn scikit-learn scipy

# %%
import sys
sys.path.append(r'C:\Users\prati\OneDrive\Desktop\Project\Player Churn')

from player_churn_analysis1 import PlayerChurnAnalysis
# Out:
# ⚠️  SHAP not available. Using sklearn feature importance.

# %%
file_path = r'C:\Users\prati\OneDrive\Desktop\Project\Player Churn\online_gaming_behavior_dataset.csv'

analyzer = PlayerChurnAnalysis()
results = analyzer.run_complete_analysis(file_path)
# Out:
# 🚀 Starting Complete Player Churn Analysis Pipeline...
# ...
# 🎮 Loading Player Behavior Dataset...
# Dataset Shape: (40034, 13)
# Features: ['PlayerID', 'Age', 'Gender', 'Location', 'GameGenre', 'PlayTimeHours', 'InGamePurchases', 'GameDifficulty', 'SessionsPerWeek', 'AvgSessionDurationMinutes', 'PlayerLevel', 'AchievementsUnlocked', 'EngagementLevel']
#
# 📊 Dataset Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40034 entries, 0 to 40033
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PlayerID                   40034 non-null  int64
#  1   Age                        40034 non-null  int64
#  2   Gender                     40034 non-null  object
#  3   Location                   40034 non-null  object
#  4   GameGenre                  40034 non-null  object
#  5   PlayTimeHours              40034 non-null  float64
#  6   InGamePurchases            40034 non-null  int64
# ...
